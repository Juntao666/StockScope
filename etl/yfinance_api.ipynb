# %%
import yfinance as yf
import os, contextlib
import pandas as pd
from pathlib import Path
import tqdm

# %% [markdown]
# **Get SP500 list**

# %%
def get_sp500_tickers_alternative():

    # fetch SP500
    csv_url = 'https://raw.githubusercontent.com/datasets/s-and-p-500-companies/master/data/constituents.csv'
    df = pd.read_csv(csv_url)

    tickers = df['Symbol'].tolist()
    tickers = [ticker.replace('.', '-') for ticker in tickers]
    
    return tickers


sp500_symbols = get_sp500_tickers_alternative()

# 打印结果进行验证
print("length of sp500_symbols:", len(sp500_symbols))
print(sp500_symbols[:10])
# Out:
# length of sp500_symbols: 503
# ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A']

# %% [markdown]
# **Use yfinance API to get the stock data in SP500 list from 2021 to now**

# %%
outfile = Path('sp500_yfinance_data.csv')
if outfile.exists():
    outfile.unlink()

# %%
# force silencing of verbose API
with open(os.devnull, 'w') as devnull:
    with contextlib.redirect_stdout(devnull):
        for i in tqdm.tqdm(range(len(sp500_symbols))):
            s = sp500_symbols[i]
            # avoid multi-level index
            data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
            # WBA will be skipped due to no data
            if len(data.index) == 0:
                continue
            df = data.reset_index()
            # insert code column
            df.insert(0, "code", s)
            
            # append to csv, only write header if file does not exist
            df.to_csv(outfile, index=False, mode="a", header=not outfile.exists())
            
print(f"All data saved to: {outfile.resolve()}")
# Out:
#   0%|          | 0/503 [00:00<?, ?it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   0%|          | 1/503 [00:00<01:57,  4.28it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   0%|          | 2/503 [00:00<01:36,  5.20it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   1%|          | 3/503 [00:00<01:37,  5.12it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   1%|          | 4/503 [00:00<01:27,  5.70it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   1%|          | 5/503 [00:00<01:19,  6.29it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   1%|          | 6/503 [00:01<01:14,  6.63it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   1%|▏         | 7/503 [00:01<01:08,  7.21it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   2%|▏         | 8/503 [00:01<01:15,  6.60it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   2%|▏         | 9/503 [00:01<01:17,  6.38it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   2%|▏         | 10/503 [00:01<01:16,  6.43it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   2%|▏         | 11/503 [00:01<01:23,  5.92it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   2%|▏         | 12/503 [00:01<01:15,  6.53it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   3%|▎         | 13/503 [00:02<01:07,  7.21it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   3%|▎         | 14/503 [00:02<01:10,  6.98it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   3%|▎         | 15/503 [00:02<01:14,  6.57it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   3%|▎         | 16/503 [00:02<01:52,  4.35it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   3%|▎         | 17/503 [00:02<01:36,  5.02it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   4%|▎         | 18/503 [00:03<01:43,  4.67it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   4%|▍         | 19/503 [00:03<01:38,  4.89it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   4%|▍         | 20/503 [00:03<01:29,  5.39it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   4%|▍         | 21/503 [00:03<01:27,  5.52it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   4%|▍         | 22/503 [00:03<01:50,  4.37it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   5%|▍         | 23/503 [00:04<01:33,  5.13it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   5%|▍         | 24/503 [00:04<01:23,  5.71it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   5%|▍         | 25/503 [00:04<01:22,  5.80it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   5%|▌         | 26/503 [00:04<01:27,  5.47it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   5%|▌         | 27/503 [00:04<01:31,  5.20it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   6%|▌         | 28/503 [00:05<01:29,  5.29it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   6%|▌         | 29/503 [00:05<01:21,  5.83it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#   6%|▌         | 30/503 [00:05<01:17,  6.12it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#
/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  93%|█████████▎| 466/503 [01:38<00:10,  3.39it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  93%|█████████▎| 467/503 [01:39<00:09,  3.60it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  93%|█████████▎| 468/503 [01:39<00:08,  4.09it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  93%|█████████▎| 469/503 [01:39<00:07,  4.35it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  93%|█████████▎| 470/503 [01:39<00:07,  4.67it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  94%|█████████▎| 471/503 [01:40<00:07,  4.29it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  94%|█████████▍| 472/503 [01:40<00:06,  4.46it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  94%|█████████▍| 473/503 [01:40<00:06,  4.37it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  94%|█████████▍| 474/503 [01:40<00:06,  4.67it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  94%|█████████▍| 475/503 [01:40<00:05,  4.88it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  95%|█████████▍| 476/503 [01:40<00:05,  5.17it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  95%|█████████▍| 477/503 [01:41<00:05,  4.48it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  95%|█████████▌| 478/503 [01:41<00:05,  4.22it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  95%|█████████▌| 479/503 [01:41<00:05,  4.03it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  95%|█████████▌| 480/503 [01:42<00:05,  4.17it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['WBA']: YFTzMissingError('possibly delisted; no timezone found')
#  96%|█████████▌| 481/503 [01:42<00:05,  4.38it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  96%|█████████▌| 482/503 [01:42<00:05,  3.88it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  96%|█████████▌| 483/503 [01:42<00:04,  4.08it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  96%|█████████▌| 484/503 [01:42<00:04,  4.39it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  96%|█████████▋| 485/503 [01:43<00:04,  4.17it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  97%|█████████▋| 486/503 [01:43<00:03,  4.66it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  97%|█████████▋| 487/503 [01:43<00:03,  4.43it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  97%|█████████▋| 488/503 [01:43<00:03,  4.02it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  97%|█████████▋| 489/503 [01:44<00:03,  3.74it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  97%|█████████▋| 490/503 [01:44<00:03,  3.57it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  98%|█████████▊| 491/503 [01:44<00:03,  3.94it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  98%|█████████▊| 492/503 [01:45<00:03,  2.94it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  98%|█████████▊| 493/503 [01:45<00:03,  3.25it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  98%|█████████▊| 494/503 [01:45<00:02,  3.16it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  98%|█████████▊| 495/503 [01:46<00:02,  3.51it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  99%|█████████▊| 496/503 [01:46<00:01,  4.21it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  99%|█████████▉| 497/503 [01:46<00:01,  4.34it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  99%|█████████▉| 498/503 [01:46<00:01,  3.35it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  99%|█████████▉| 499/503 [01:47<00:01,  3.72it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
#  99%|█████████▉| 500/503 [01:47<00:00,  3.96it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
# 100%|█████████▉| 501/503 [01:47<00:00,  4.35it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
# 100%|█████████▉| 502/503 [01:47<00:00,  4.34it/s]/var/folders/4k/11kxhlxx3bl54nl7931sq1w80000gn/T/ipykernel_5469/2256365825.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(s, start='2021-01-01', end='2025-11-07', multi_level_index = False)
# [*********************100%***********************]  1 of 1 completed
# 100%|██████████| 503/503 [01:47<00:00,  4.66it/s]
# All data saved to: /Users/zhangyici/Desktop/研一 Fall/DB/Final_Project/StockScope/etl/sp500_yfinance_data.csv

# %%
dat = yf.Ticker("AMZN")
dat.info
# Out:
# {'address1': '410 Terry Avenue North',
#  'city': 'Seattle',
#  'state': 'WA',
#  'zip': '98109-5210',
#  'country': 'United States',
#  'phone': '206 266 1000',
#  'website': 'https://www.amazon.com',
#  'industry': 'Internet Retail',
#  'industryKey': 'internet-retail',
#  'industryDisp': 'Internet Retail',
#  'sector': 'Consumer Cyclical',
#  'sectorKey': 'consumer-cyclical',
#  'sectorDisp': 'Consumer Cyclical',
#  'longBusinessSummary': "Amazon.com, Inc. engages in the retail sale of consumer products, advertising, and subscriptions service through online and physical stores in North America and internationally. The company operates through three segments: North America, International, and Amazon Web Services (AWS). It also manufactures and sells electronic devices, including Kindle, fire tablets, fire TVs, echo, ring, blink, and eero; and develops and produces media content. In addition, the company offers programs that enable sellers to sell their products in its stores; and programs that allow authors, independent publishers, musicians, filmmakers, Twitch streamers, skill and app developers, and others to publish and sell content. Further, it provides compute, storage, database, analytics, machine learning, and other services, as well as advertising services through programs, such as sponsored ads, display, and video advertising. Additionally, the company offers Amazon Prime, a membership program. The company's products offered through its stores include merchandise and content purchased for resale and products offered by third-party sellers. It also provides AgentCore services, such as AgentCore Runtime, AgentCore Memory, AgentCore Observability, AgentCore Identity, AgentCore Gateway, AgentCore Browser, and AgentCore Code Interpreter. It serves consumers, sellers, developers, enterprises, content creators, advertisers, and employees. Amazon.com, Inc. was incorporated in 1994 and is headquartered in Seattle, Washington.",
#  'fullTimeEmployees': 1578000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Jeffrey P. Bezos',
#    'age': 60,
#    'title': 'Founder & Executive Chairman',
#    'yearBorn': 1964,
#    'fiscalYear': 2024,
#    'totalPay': 1681840,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Andrew R. Jassy',
#    'age': 56,
#    'title': 'President, CEO & Director',
#    'yearBorn': 1968,
#    'fiscalYear': 2024,
#    'totalPay': 1596889,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Brian T. Olsavsky',
#    'age': 60,
#    'title': 'Senior VP & CFO',
#    'yearBorn': 1964,
#    'fiscalYear': 2024,
#    'totalPay': 371900,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. David A. Zapolsky J.D.',
#    'age': 60,
#    'title': 'Senior VP, Chief Global Affairs & Legal Officer',
#    'yearBorn': 1964,
#    'fiscalYear': 2024,
#    'totalPay': 371900,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Douglas J. Herrington',
#    'age': 57,
#    'title': 'Chief Executive Officer of Worldwide Amazon Stores',
#    'yearBorn': 1967,
#    'fiscalYear': 2024,
#    'totalPay': 386435,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Matthew S. Garman',
#    'age': 47,
#    'title': 'Chief Executive Officer of Amazon Web Series',
#    'yearBorn': 1977,
#    'fiscalYear': 2024,
#    'totalPay': 384275,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Shelley L. Reynolds',
#    'age': 59,
#    'title': 'VP, Worldwide Controller & Principal Accounting Officer',
#    'yearBorn': 1965,
#    'fiscalYear': 2024,
#    'totalPay': 163200,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Werner  Vogels',
#    'title': 'Chief Technology Officer',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Dave  Fildes',
#    'title': 'Vice President of Investor Relations',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Drew  Herdener',
#    'title': 'Senior Vice President of Communications & Corporate Responsibility',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 2,
#  'boardRisk': 8,
#  'compensationRisk': 10,
#  'shareHolderRightsRisk': 3,
#  'overallRisk': 9,
#  'governanceEpochDate': 1761955200,
#  'compensationAsOfEpochDate': 1735603200,
#  'irWebsite': 'http://phx.corporate-ir.net/phoenix.zhtml?c=97664&p=irol-irhome',
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 243.04,
#  'open': 242.9,
#  'dayLow': 238.49,
#  'dayHigh': 244.9,
#  'regularMarketPreviousClose': 243.04,
#  'regularMarketOpen': 242.9,
#  'regularMarketDayLow': 238.49,
#  'regularMarketDayHigh': 244.9,
#  'payoutRatio': 0.0,
#  'beta': 1.368,
#  'trailingPE': 34.472496,
#  'forwardPE': 39.741463,
#  'volume': 46128349,
#  'regularMarketVolume': 46128349,
#  'averageVolume': 45938100,
#  'averageVolume10days': 68645080,
#  'averageDailyVolume10Day': 68645080,
#  'bid': 244.46,
#  'ask': 255.13,
#  'bidSize': 1,
#  'askSize': 1,
#  'marketCap': 2612795801600,
#  'fiftyTwoWeekLow': 161.38,
#  'fiftyTwoWeekHigh': 258.6,
#  'allTimeHigh': 258.6,
#  'allTimeLow': 0.065625,
#  'priceToSalesTrailing12Months': 3.7793756,
#  'fiftyDayAverage': 227.3862,
#  'twoHundredDayAverage': 214.9185,
#  'trailingAnnualDividendRate': 0.0,
#  'trailingAnnualDividendYield': 0.0,
#  'currency': 'USD',
#  'tradeable': False,
#  'enterpriseValue': 2679036706816,
#  'profitMargins': 0.11063,
#  'floatShares': 9700943421,
#  'sharesOutstanding': 10690216011,
#  'sharesShort': 74507966,
#  'sharesShortPriorMonth': 69908794,
#  'sharesShortPreviousMonthDate': 1757894400,
#  'dateShortInterest': 1760486400,
#  'sharesPercentSharesOut': 0.0069999998,
#  'heldPercentInsiders': 0.09184,
#  'heldPercentInstitutions': 0.66185,
#  'shortRatio': 1.56,
#  'shortPercentOfFloat': 0.0077,
#  'impliedSharesOutstanding': 10690216011,
#  'bookValue': 34.587,
#  'priceToBook': 7.066528,
#  'lastFiscalYearEnd': 1735603200,
#  'nextFiscalYearEnd': 1767139200,
#  'mostRecentQuarter': 1759190400,
#  'earningsQuarterlyGrowth': 0.382,
#  'netIncomeToCommon': 76482002944,
#  'trailingEps': 7.09,
#  'forwardEps': 6.15,
#  'lastSplitFactor': '20:1',
#  'lastSplitDate': 1654473600,
#  'enterpriseToRevenue': 3.875,
#  'enterpriseToEbitda': 19.177,
#  '52WeekChange': 0.181638,
#  'SandP52WeekChange': 0.12121439,
#  'quoteType': 'EQUITY',
#  'currentPrice': 244.41,
#  'targetHighPrice': 351.87,
#  'targetLowPrice': 250.0,
#  'targetMeanPrice': 292.27655,
#  'targetMedianPrice': 300.0,
#  'recommendationMean': 1.29851,
#  'recommendationKey': 'strong_buy',
#  'numberOfAnalystOpinions': 61,
#  'totalCash': 94196998144,
#  'totalCashPerShare': 8.812,
#  'ebitda': 139696996352,
#  'totalDebt': 160437993472,
#  'quickRatio': 0.76,
#  'currentRatio': 1.009,
#  'totalRevenue': 691330023424,
#  'debtToEquity': 43.405,
#  'revenuePerShare': 65.12,
#  'returnOnAssets': 0.07495,
#  'returnOnEquity': 0.24327,
#  'grossProfits': 345982009344,
#  'freeCashflow': 26080000000,
#  'operatingCashflow': 130690998272,
#  'earningsGrowth': 0.364,
#  'revenueGrowth': 0.134,
#  'grossMargins': 0.50046,
#  'ebitdaMargins': 0.20207001,
#  'operatingMargins': 0.11057,
#  'financialCurrency': 'USD',
#  'symbol': 'AMZN',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'shortName': 'Amazon.com, Inc.',
#  'longName': 'Amazon.com, Inc.',
#  'regularMarketChangePercent': 0.563698,
#  'regularMarketPrice': 244.41,
#  'messageBoardId': 'finmb_18749',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'gmtOffSetMilliseconds': -18000000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'marketState': 'CLOSED',
#  'exchange': 'NMS',
#  'corporateActions': [],
#  'postMarketTime': 1762563588,
#  'regularMarketTime': 1762549202,
#  'hasPrePostMarketData': True,
#  'firstTradeDateMilliseconds': 863703000000,
#  'postMarketChangePercent': 0.30276594,
#  'earningsTimestamp': 1761854400,
#  'earningsTimestampStart': 1761854400,
#  'earningsTimestampEnd': 1761854400,
#  'earningsCallTimestampStart': 1761858000,
#  'earningsCallTimestampEnd': 1761858000,
#  'isEarningsDateEstimate': False,
#  'epsTrailingTwelveMonths': 7.09,
#  'epsForward': 6.15,
#  'epsCurrentYear': 7.02332,
#  'priceEpsCurrentYear': 34.79978,
#  'fiftyDayAverageChange': 17.023804,
#  'fiftyDayAverageChangePercent': 0.07486736,
#  'twoHundredDayAverageChange': 29.4915,
#  'twoHundredDayAverageChangePercent': 0.13722178,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 0,
#  'averageAnalystRating': '1.3 - Strong Buy',
#  'cryptoTradeable': False,
#  'postMarketPrice': 245.15,
#  'postMarketChange': 0.73999023,
#  'regularMarketChange': 1.37001,
#  'regularMarketDayRange': '238.49 - 244.9',
#  'fullExchangeName': 'NasdaqGS',
#  'averageDailyVolume3Month': 45938100,
#  'fiftyTwoWeekLowChange': 83.03,
#  'fiftyTwoWeekLowChangePercent': 0.5144999,
#  'fiftyTwoWeekRange': '161.38 - 258.6',
#  'fiftyTwoWeekHighChange': -14.190002,
#  'fiftyTwoWeekHighChangePercent': -0.054872397,
#  'fiftyTwoWeekChangePercent': 18.1638,
#  'displayName': 'Amazon.com',
#  'trailingPegRatio': 1.9715}

# %% [markdown]
# **Get Company Information CSV**

# %%
import csv

# %%
outfile = Path('sp500_company_data.csv')
header = [
    "code", "name", "full_time_employees",
    "long_business_summary", "industry", "city", "state", "country"
]
if not outfile.exists():
    with open(outfile, "w", newline='', encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(header)

# %%
# force silencing of verbose API
with open(os.devnull, 'w') as devnull:
    with contextlib.redirect_stdout(devnull):
        for i in tqdm.tqdm(range(len(sp500_symbols))):
            s = sp500_symbols[i]
            data = yf.Ticker(s).info
            row = [
                s, # code
                data.get("longName", "hahaha"), # name, make sure name exists
                data.get("fullTimeEmployees"),
                data.get("longBusinessSummary"),
                data.get("industry"),
                data.get("city"),
                data.get("state"),
                data.get("country")
            ]
            with open(outfile, "a", newline='', encoding="utf-8") as f:
                writer = csv.writer(f)
                writer.writerow(row)
            
print(f"All data saved to: {outfile.resolve()}")
# Out:
#  95%|█████████▌| 480/503 [01:35<00:04,  5.23it/s]HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: WBA"}}}
# 100%|██████████| 503/503 [01:40<00:00,  5.03it/s]
# All data saved to: /Users/zhangyici/Desktop/研一 Fall/DB/Final_Project/StockScope/etl/sp500_company_data.csv

# %% [markdown]
# **Sentiment Score**

# %%
import requests
import csv
import time
from datetime import datetime
from pathlib import Path
import yfinance as yf
import pandas as pd
# Out:
# /Users/jeffvan/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# get sp500 list
def get_sp500_tickers_alternative():

    # fetch SP500
    csv_url = 'https://raw.githubusercontent.com/datasets/s-and-p-500-companies/master/data/constituents.csv'
    df = pd.read_csv(csv_url)

    tickers = df['Symbol'].tolist()
    tickers = [ticker.replace('.', '-') for ticker in tickers]
    
    return tickers


sp500_symbols = get_sp500_tickers_alternative()

# validation
print("length of sp500_symbols:", len(sp500_symbols))
print(sp500_symbols[:10])
# Out:
# length of sp500_symbols: 503
# ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A']

# %%
# basic info
# API_KEY = "4WH041V75ZSYLZDY" #ZYC's API key

# API_KEY = "5IOK22YFLKBUDHL"         # Jack's API key
API_KEY = "LONB725JY0NFBGY6"          # WXY's
# API_KEY = "8TOEQYXQGWV486I1"    #XZJ
TIME_FROM = "20210101T0130"
LIMIT = 1000
BASE_URL = "https://www.alphavantage.co/query"

# %%
sp500_set = set(sp500_symbols)
NEWS_DETAIL_CSV = Path("news_detail.csv")
NEWS_COMPANY_SENTIMENT_CSV = Path("news_company_sentiment.csv")
REQUEST_SLEEP_SECONDS = 15

# %%
TODAY_TICKERS = sp500_symbols[225:250]

# %%
TODAY_TICKERS
# Out:
# ['HCA',
#  'DOC',
#  'HSIC',
#  'HSY',
#  'HPE',
#  'HLT',
#  'HOLX',
#  'HD',
#  'HON',
#  'HRL',
#  'HST',
#  'HWM',
#  'HPQ',
#  'HUBB',
#  'HUM',
#  'HBAN',
#  'HII',
#  'IBM',
#  'IEX',
#  'IDXX',
#  'ITW',
#  'INCY',
#  'IR',
#  'PODD',
#  'INTC']

# %%
def parse_timestamp(time_str: str) -> str:
    """
    transform to SQL timestamp
    input format: '20251116T140100'
    return: '2025-11-16 14:01:00'
    """
    try:
        dt = datetime.strptime(time_str, "%Y%m%dT%H%M%S")
        return dt.strftime("%Y-%m-%d %H:%M:%S")
    except Exception:
        return ""

# %%
def fetch_news_for_ticker(ticker: str):
    """
    get the json of news of one ticker
    """
    params = {
        "function": "NEWS_SENTIMENT",
        "tickers": ticker,
        "time_from": TIME_FROM,
        "limit": LIMIT,
        "apikey": API_KEY,
    }

    try:
        resp = requests.get(BASE_URL, params=params, timeout=30)
    except Exception as e:
        print(f"[ERROR] Request failed for {ticker}: {e}")
        return None

    if resp.status_code != 200:
        print(f"[ERROR] HTTP {resp.status_code} for {ticker}: {resp.text[:200]}")
        return None

    try:
        data = resp.json()
    except Exception as e:
        print(f"[ERROR] JSON decode failed for {ticker}: {e}")
        return None

    if "Error Message" in data or "Note" in data:
        print(f"[WARN] API error / note for {ticker}: {data.get('Error Message') or data.get('Note')}")
        return None

    return data

# %%
def load_existing_news():
    """
    get the current news_key_to_id: (url, time_published) -> id mapping from current csv file
    """
    news_key_to_id = {}
    max_id = 0

    if NEWS_DETAIL_CSV.exists():
        with NEWS_DETAIL_CSV.open("r", newline="", encoding="utf-8") as f:
            reader = csv.DictReader(f)
            for row in reader:
                try:
                    nid = int(row["id"])
                except (KeyError, ValueError):
                    continue
                url = row.get("url")
                ts = row.get("timestamp_raw")
                if not url or not ts:
                    continue
                news_key_to_id[(url, ts)] = nid
                if nid > max_id:
                    max_id = nid

    next_news_id = max_id + 1 if max_id > 0 else 1
    return news_key_to_id, next_news_id

# %%
def load_existing_sentiments():
    """
    get current sentiment_written: set((company_code, news_id)) from current csv file
    """
    sentiment_written = set()
    if NEWS_COMPANY_SENTIMENT_CSV.exists():
        with NEWS_COMPANY_SENTIMENT_CSV.open("r", newline="", encoding="utf-8") as f:
            reader = csv.DictReader(f)
            for row in reader:
                company_code = row.get("company_code")
                try:
                    news_id = int(row.get("news_id", ""))
                except (TypeError, ValueError):
                    continue
                if company_code and news_id:
                    sentiment_written.add((company_code, news_id))
    return sentiment_written

# %%
# load current information for avoiding duplication, calls every time as long as the csv file updates
news_key_to_id, next_news_id = load_existing_news()
sentiment_written = load_existing_sentiments()
print(f"Loaded {len(news_key_to_id)} existing news, next_news_id = {next_news_id}")
print(f"Loaded {len(sentiment_written)} existing sentiments, ready to go")

# append model, write header if the file does not exist
detail_file_exists = NEWS_DETAIL_CSV.exists()
sent_file_exists = NEWS_COMPANY_SENTIMENT_CSV.exists()

with NEWS_DETAIL_CSV.open("a", newline="", encoding="utf-8") as f_detail, \
     NEWS_COMPANY_SENTIMENT_CSV.open("a", newline="", encoding="utf-8") as f_sent:

    # to avoid duplication, add one more row timestamp_raw
    detail_fieldnames = ["id", "url", "title", "timestamp", "timestamp_raw"]
    sentiment_fieldnames = ["company_code", "news_id", "sentiment_score", "sentiment_level"]

    detail_writer = csv.DictWriter(f_detail, fieldnames=detail_fieldnames)
    sentiment_writer = csv.DictWriter(f_sent, fieldnames=sentiment_fieldnames)

    # the file does not exist, add header
    if not detail_file_exists:
        detail_writer.writeheader()
    if not sent_file_exists:
        sentiment_writer.writeheader()

    # get target tickers
    for idx, ticker in enumerate(TODAY_TICKERS, start=1):
        print(f"=== [{idx}/{len(TODAY_TICKERS)}] Fetching news for {ticker} ===")

        data = fetch_news_for_ticker(ticker)
        if not data:
            print(f"[WARN] Skip {ticker} due to error/empty response")
            time.sleep(REQUEST_SLEEP_SECONDS)
            continue

        feed = data.get("feed", [])
        print(f"Got {len(feed)} news items for {ticker}")

        for article in feed:
            url = article.get("url")
            title = article.get("title")
            time_published = article.get("time_published")

            if not url or not title or not time_published:
                continue

            news_key = (url, time_published)

            # !!!IMPORTANT!!! if it is first time to encounter this news, get a new news_id for this news
            if news_key not in news_key_to_id:
                news_id = next_news_id
                # store this news to news_id mapping
                news_key_to_id[news_key] = news_id
                next_news_id += 1

                ts_str = parse_timestamp(time_published)

                detail_writer.writerow({
                    "id": news_id,
                    "url": url,
                    "title": title,
                    "timestamp": ts_str,
                    "timestamp_raw": time_published,
                })
            else:
                news_id = news_key_to_id[news_key]

            # for each tickers sentiment score, write into NewsCompanySentiment
            # avoid duplication using sentiment_written
            ticker_sentiments = article.get("ticker_sentiment", [])
            for tsent in ticker_sentiments:
                company_code = tsent.get("ticker")
                if not company_code:
                    continue

                # only store company in sp500_set
                if company_code not in sp500_set:
                    continue

                score_str = tsent.get("ticker_sentiment_score")
                label = tsent.get("ticker_sentiment_label")

                if score_str is None or label is None:
                    continue

                try:
                    score = float(score_str)
                except ValueError:
                    continue
                
                # !!!IMPORTANT!!! avoid duplication on sentiment, avoid same company_code, news_id rows/pairs
                key = (company_code, news_id)
                # if duplicates, continue to next company 
                if key in sentiment_written:
                    continue
                
                sentiment_writer.writerow({
                    "company_code": company_code,
                    "news_id": news_id,
                    "sentiment_score": f"{score:.6f}",
                    "sentiment_level": label,
                })
                # add the new company_code, news_id pair
                sentiment_written.add(key)

        print(f"Sleeping {REQUEST_SLEEP_SECONDS} seconds to respect API rate limit...")
        time.sleep(REQUEST_SLEEP_SECONDS)

print("Done appending! Now the CSV fild has been updated: ")
print(f" - {NEWS_DETAIL_CSV.resolve()}")
print(f" - {NEWS_COMPANY_SENTIMENT_CSV.resolve()}")
# Out:
# Loaded 112291 existing news, next_news_id = 112292
# Loaded 257176 existing sentiments, ready to go
# === [1/25] Fetching news for HCA ===
# Got 748 news items for HCA
# Sleeping 15 seconds to respect API rate limit...
# === [2/25] Fetching news for DOC ===
# Got 87 news items for DOC
# Sleeping 15 seconds to respect API rate limit...
# === [3/25] Fetching news for HSIC ===
# Got 713 news items for HSIC
# Sleeping 15 seconds to respect API rate limit...
# === [4/25] Fetching news for HSY ===
# Got 715 news items for HSY
# Sleeping 15 seconds to respect API rate limit...
# === [5/25] Fetching news for HPE ===
# Got 648 news items for HPE
# Sleeping 15 seconds to respect API rate limit...
# === [6/25] Fetching news for HLT ===
# Got 696 news items for HLT
# Sleeping 15 seconds to respect API rate limit...
# === [7/25] Fetching news for HOLX ===
# Got 746 news items for HOLX
# Sleeping 15 seconds to respect API rate limit...
# === [8/25] Fetching news for HD ===
# Got 706 news items for HD
# Sleeping 15 seconds to respect API rate limit...
# === [9/25] Fetching news for HON ===
# Got 681 news items for HON
# Sleeping 15 seconds to respect API rate limit...
# === [10/25] Fetching news for HRL ===
# Got 697 news items for HRL
# Sleeping 15 seconds to respect API rate limit...
# === [11/25] Fetching news for HST ===
# Got 482 news items for HST
# Sleeping 15 seconds to respect API rate limit...
# === [12/25] Fetching news for HWM ===
# Got 647 news items for HWM
# Sleeping 15 seconds to respect API rate limit...
# === [13/25] Fetching news for HPQ ===
# Got 670 news items for HPQ
# Sleeping 15 seconds to respect API rate limit...
# === [14/25] Fetching news for HUBB ===
# Got 556 news items for HUBB
# Sleeping 15 seconds to respect API rate limit...
# === [15/25] Fetching news for HUM ===
# Got 709 news items for HUM
# Sleeping 15 seconds to respect API rate limit...
# === [16/25] Fetching news for HBAN ===
# Got 0 news items for HBAN
# Sleeping 15 seconds to respect API rate limit...
# === [17/25] Fetching news for HII ===
# Got 482 news items for HII
# Sleeping 15 seconds to respect API rate limit...
# === [18/25] Fetching news for IBM ===
# Got 696 news items for IBM
# Sleeping 15 seconds to respect API rate limit...
# === [19/25] Fetching news for IEX ===
# Got 730 news items for IEX
# Sleeping 15 seconds to respect API rate limit...
# === [20/25] Fetching news for IDXX ===
# Got 632 news items for IDXX
# Sleeping 15 seconds to respect API rate limit...
# === [21/25] Fetching news for ITW ===
# Got 702 news items for ITW
# Sleeping 15 seconds to respect API rate limit...
# === [22/25] Fetching news for INCY ===
# Got 690 news items for INCY
# Sleeping 15 seconds to respect API rate limit...
# === [23/25] Fetching news for IR ===
# Got 731 news items for IR
# Sleeping 15 seconds to respect API rate limit...
# === [24/25] Fetching news for PODD ===
# Got 725 news items for PODD
# Sleeping 15 seconds to respect API rate limit...
# === [25/25] Fetching news for INTC ===
# Got 684 news items for INTC
# Sleeping 15 seconds to respect API rate limit...
# Done appending! Now the CSV fild has been updated:
#  - /Users/jeffvan/Desktop/My Stuff/Courses/CIS 5500/StockScope/StockScope/etl/news_detail.csv
#  - /Users/jeffvan/Desktop/My Stuff/Courses/CIS 5500/StockScope/StockScope/etl/news_company_sentiment.csv
